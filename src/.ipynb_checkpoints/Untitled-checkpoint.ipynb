# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('file.csv')

# %%
df
# Out:
#            Process  Replicate                   Gene_tree Species_Tree  \
# 0     True Process          0      ((((C,C),A),A),(B,C));   ((C,B),A);
# 1    Our_algorithm          0      ((((C,C),A),A),(B,C));   ((C,B),A);
# 2     True Process          1          ((((A,A),B),C),A);   ((C,B),A);
# 3    Our_algorithm          1          ((((A,A),B),C),A);   ((C,B),A);
# 4     True Process          2                  ((C,B),B);   ((C,B),A);
# ..             ...        ...                         ...          ...
# 195  Our_algorithm         97                      (A,A);   ((C,B),A);
# 196   True Process         98                      (B,C);   ((C,B),A);
# 197  Our_algorithm         98                      (B,C);   ((C,B),A);
# 198   True Process         99  (C,(((B,B),((B,C),C)),A));   ((C,B),A);
# 199  Our_algorithm         99  (C,(((B,B),((B,C),C)),A));   ((C,B),A);
#
#      Duplication  NNI  Loss
# 0              5    0     2
# 1              3    1     0
# ...

# %%
sns.boxplot(x=df["Replicate"], y=df["Duplication"],hue=df['Process'] );
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Duplication', 'Loss', 'NNI')
#
# The above exception was the direct cause of the following exception:
#
# ...
